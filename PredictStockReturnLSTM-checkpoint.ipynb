# %%
from nsepy import get_history
from datetime import date
import glob
import pandas as pd
import numpy as np
import time

import warnings
warnings.filterwarnings('ignore')

import nsepy

from nsepy import get_history
import tensorflow as tf

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation

# %%
# %run -i C:/WS/Project1/kite_hist_data as kite
# C:/Users/Srujan/Downloads/EAI/kite hist data.py
# Out:
# https://kite.trade/connect/login?api_key=3jshozhjv1djt4ak&v=3
# https://kite.trade/?status=success&request_token=Iu52AnjmflGU64G88HeZ2nr95AkPnLIT&action=login&type=login
# success

# %%
instruments = pd.DataFrame(kite.instruments())

# %%
dd = instruments[(instruments['tradingsymbol'] == 'SBIN') & (instruments['instrument_type'] == 'EQ')]

dd = dd.head(1)
#             to_date = date.today()

from_date = '2017-03-01'

to_date = '2021-12-20'

ttoken = dd['instrument_token'].item()

dt_stock = kite.historical_data(ttoken, from_date, to_date,'day',0,oi=1)

dt_stock = pd.DataFrame(dt_stock)

dt_stock['Symbol'] = 'SBIN'

# %%
#dt_stock.to_csv("data_sbi.csv")

# %%
#dt_stock = pd.read_csv("data_sbi_m.csv")

# %%
#dt_stock.volume.shift(1)

# %%
dt_stock["returns_numeric"] = dt_stock.close - dt_stock.close.shift(1)
dt_stock["returns_percentage"] = (dt_stock.returns_numeric/ dt_stock.close.shift(1))*100
dt_stock["volume_change_numeric"] = dt_stock.volume - dt_stock.volume.shift(1)
dt_stock["volume_change_percentage"] = (dt_stock.volume_change_numeric / dt_stock.volume.shift(1))*100

# %%
dt_stock.head()
# Out:
#                        date   open    high     low   close   volume  oi  \
# 0 2017-03-01 00:00:00+05:30  270.4  273.10  270.25  271.95  1157627   0
# 1 2017-03-02 00:00:00+05:30  273.5  274.60  266.00  267.00  1130527   0
# 2 2017-03-03 00:00:00+05:30  266.4  268.60  264.50  265.15   763059   0
# 3 2017-03-06 00:00:00+05:30  267.0  270.45  266.60  269.90   623060   0
# 4 2017-03-07 00:00:00+05:30  270.8  271.00  266.45  268.05   441030   0
#
#   Symbol  returns_numeric  returns_percentage  volume_change_numeric  \
# 0   SBIN              NaN                 NaN                    NaN
# 1   SBIN            -4.95           -1.820188               -27100.0
# 2   SBIN            -1.85           -0.692884              -367468.0
# 3   SBIN             4.75            1.791439              -139999.0
# 4   SBIN            -1.85           -0.685439              -182030.0
#
#    volume_change_percentage
# 0                       NaN
# 1                 -2.340996
# 2                -32.504133
# 3                -18.347074
# 4                -29.215485

# %%
dt_stock = dt_stock.dropna()

# %%
#setting index as date
dt_stock['date'] = pd.to_datetime(dt_stock.date,format='%Y-%m-%d')
dt_stock.index = dt_stock['date']

#plot
plt.figure(figsize=(16,8))
plt.plot(dt_stock['close'][0:len(dt_stock.close)-1], label='Close Price history')

# %%
#setting index as date
dt_stock['date'] = pd.to_datetime(dt_stock.date,format='%Y-%m-%d')
dt_stock.index = dt_stock['date']

#plot
plt.figure(figsize=(16,8))
plt.plot(dt_stock['returns_numeric'][0:len(dt_stock.returns_numeric)-1], label='Returns Price history')

# %%
#setting index as date
dt_stock['date'] = pd.to_datetime(dt_stock.date,format='%Y-%m-%d')
dt_stock.index = dt_stock['date']

#plot
plt.figure(figsize=(16,8))
plt.plot(dt_stock['returns_percentage'][0:len(dt_stock.returns_numeric)-1], label='Returns Percentage history')

# %%
#setting index as date
dt_stock['date'] = pd.to_datetime(dt_stock.date,format='%Y-%m-%d')
dt_stock.index = dt_stock['date']

#plot
plt.figure(figsize=(16,8))
plt.plot(dt_stock['volume_change_numeric'][0:len(dt_stock.returns_numeric)-1], label='volume change history')

# %% [markdown]
# # unscaled

# %%
#creating dataframe unscaled
'''data = dt_stock.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(dt_stock)),columns=['date', 'close','volume'])
for i in range(0,len(data)):
    new_data['date'][i] = data['date'][i]
    new_data['close'][i] = data['close'][i]
    new_data['volume'][i] = data['volume'][i]


#setting index
print(new_data.shape)
new_data.index = new_data.date
new_data.drop('date', axis=1, inplace=True)
print(new_data.shape)

#creating train and test sets
dataset = new_data.values
print(dataset.shape)



#print(len(valid))
#converting dataset into x_train and y_train
#scaler = MinMaxScaler(feature_range=(0, 1))
#scaled_data = scaler.fit_transform(dataset)

train = dataset[0:int(len(dataset)*0.7),:]
print("train shape",train.shape)
valid = dataset[int(len(dataset)*0.7):,:]

x_train, y_train = [], []
for i in range(90,len(train)):
    x_train.append(train[i-90:i,])
    y_train.append(train[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

print("x-train 90 days shape",x_train.shape)
print("y-shape 90 days shape",y_train.shape)

    
x_test, y_test = [], []
for i in range(90,len(valid)):
    x_test.append(valid[i-90:i,])
    y_test.append(valid[i,0])
x_test, y_test = np.array(x_test), np.array(y_test)

#x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print("x-test 90 days shape",x_test.shape)
print("y-test 90 days shape",y_test.shape)


x_train1 = np.reshape(x_train[0],(1,-1))
for i in range(1,len(x_train)):
    r1 = np.reshape(x_train[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_train1 = np.vstack((x_train1,r1))
pd.DataFrame(x_train1).to_csv("train_data_unscaled_lstm.csv")
print(pd.DataFrame(x_train1).head(3))
print("x-train1 90 days shape",x_train1.shape)
#print("x-train1 90 days head ",x_train1.head())
print("y-shape 90 days shape",y_train.shape)


x_test1 = np.reshape(x_test[0],(1,-1))
for i in range(1,len(x_test)):
    r1 = np.reshape(x_test[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_test1 = np.vstack((x_test1,r1))
x_test.shape
pd.DataFrame(x_test1).to_csv("test_data_unscaled_lstm.csv")

#print(pd.DataFrame(x_test).head(3))
print("x-test1 90 days shape",x_test.shape)
print("y-test 90 days shape",y_test.shape) '''
# Out:
# 'data = dt_stock.sort_index(ascending=True, axis=0)\nnew_data = pd.DataFrame(index=range(0,len(dt_stock)),columns=[\'date\', \'close\',\'volume\'])\nfor i in range(0,len(data)):\n    new_data[\'date\'][i] = data[\'date\'][i]\n    new_data[\'close\'][i] = data[\'close\'][i]\n    new_data[\'volume\'][i] = data[\'volume\'][i]\n\n\n#setting index\nprint(new_data.shape)\nnew_data.index = new_data.date\nnew_data.drop(\'date\', axis=1, inplace=True)\nprint(new_data.shape)\n\n#creating train and test sets\ndataset = new_data.values\nprint(dataset.shape)\n\n\n\n#print(len(valid))\n#converting dataset into x_train and y_train\n#scaler = MinMaxScaler(feature_range=(0, 1))\n#scaled_data = scaler.fit_transform(dataset)\n\ntrain = dataset[0:int(len(dataset)*0.7),:]\nprint("train shape",train.shape)\nvalid = dataset[int(len(dataset)*0.7):,:]\n\nx_train, y_train = [], []\nfor i in range(90,len(train)):\n    x_train.append(train[i-90:i,])\n    y_train.append(train[i,0])\nx_train, y_train = np.array(x_train), np.array(y_train)\n\nprint("x-train 90 days shape",x_train.shape)\nprint("y-shape 90 days shape",y_train.shape)\n\n    \nx_test, y_test = [], []\nfor i in range(90,len(valid)):\n    x_test.append(valid[i-90:i,])\n    y_test.append(valid[i,0])\nx_test, y_test = np.array(x_test), np.array(y_test)\n\n#x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))\nprint("x-test 90 days shape",x_test.shape)\nprint("y-test 90 days shape",y_test.shape)\n\n\nx_train1 = np.reshape(x_train[0],(1,-1))\nfor i in range(1,len(x_train)):\n    r1 = np.reshape(x_train[i],(1,-1))\n    #r2 = np.reshape(x_train[1],(1,-1))\n    x_train1 = np.vstack((x_train1,r1))\npd.DataFrame(x_train1).to_csv("train_data_unscaled_lstm.csv")\nprint(pd.DataFrame(x_train1).head(3))\nprint("x-train1 90 days shape",x_train1.shape)\n#print("x-train1 90 days head ",x_train1.head())\nprint("y-shape 90 days shape",y_train.shape)\n\n\nx_test1 = np.reshape(x_test[0],(1,-1))\nfor i in range(1,len(x_test)):\n    r1 = np.reshape(x_test[i],(1,-1))\n    #r2 = np.reshape(x_train[1],(1,-1))\n    x_test1 = np.vstack((x_test1,r1))\nx_test.shape\npd.DataFrame(x_test1).to_csv("test_data_unscaled_lstm.csv")\n\n#print(pd.DataFrame(x_test).head(3))\nprint("x-test1 90 days shape",x_test.shape)\nprint("y-test 90 days shape",y_test.shape) '

# %% [markdown]
# # scaled

# %%
#dt_stock = dt_stock.dropna()

# %%
#creating dataframe scaled
data = dt_stock.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(dt_stock)),columns=['date', 'returns_percentage','volume_change_percentage'])
for i in range(0,len(data)):
    new_data['date'][i] = data['date'][i]
    new_data['returns_percentage'][i] = data['returns_percentage'][i]
    new_data['volume_change_percentage'][i] = data['volume_change_percentage'][i]


#setting index
#print(new_data.shape)
new_data.index = new_data.date
new_data.drop('date', axis=1, inplace=True)
print("data shape",new_data.shape)

#creating train and test sets
dataset = new_data.values
#print(dataset.shape)



#print(len(valid))
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
print("Scaling done")
train = scaled_data[0:int(len(scaled_data)*0.7),:]
print("train shape",train.shape)
valid = scaled_data[int(len(scaled_data)*0.7):,:]
print("test shape",valid.shape)


x_train, y_train = [], []
for i in range(7,len(train)):
    x_train.append(train[i-7:i,])
    y_train.append(train[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

print("x-train 7 days shape",x_train.shape)
print("y-shape 7 days shape",y_train.shape)

    
x_test, y_test = [], []
for i in range(7,len(valid)):
    x_test.append(valid[i-7:i,])
    y_test.append(valid[i,0])
x_test, y_test = np.array(x_test), np.array(y_test)

#x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print("x-test 7 days shape",x_test.shape)
print("y-test 7 days shape",y_test.shape)


x_train1 = np.reshape(x_train[0],(1,-1))
for i in range(1,len(x_train)):
    r1 = np.reshape(x_train[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_train1 = np.vstack((x_train1,r1))
#pd.DataFrame(x_train1).to_csv("train_data_lstm.csv")
#print(pd.DataFrame(x_train1).head(3))
print("x-train1 7 days shape",x_train1.shape)
#print("x-train1 90 days head ",x_train1.head())
print("y-shape 7 days shape",y_train.shape)
print("y-train 7 days head ",y_train[0:2])


x_test1 = np.reshape(x_test[0],(1,-1))
for i in range(1,len(x_test)):
    r1 = np.reshape(x_test[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_test1 = np.vstack((x_test1,r1))
#x_test.shape
#pd.DataFrame(x_test1).to_csv("test_data_lstm.csv")
#print(pd.DataFrame(x_test1).head(2))
#print(pd.DataFrame(x_test).head(3))
print("x-test1 7 days shape",x_test1.shape)
print("y-test 7 days shape",y_test.shape)


x_train1 = np.reshape(x_train1, (x_train1.shape[0],x_train1.shape[1],1))
print("x-train1 7 days reshaped",x_train1.shape)

y_train = np.reshape(y_train, (y_train.shape[0],1,1))
print("y_train 7 days reshaped",y_train.shape)
# Out:
# data shape (1190, 2)
# Scaling done
# train shape (833, 2)
# test shape (357, 2)
# x-train 7 days shape (826, 7, 2)
# y-shape 7 days shape (826,)
# x-test 7 days shape (350, 7, 2)
# y-test 7 days shape (350,)
# x-train1 7 days shape (826, 14)
# y-shape 7 days shape (826,)
# y-train 7 days head  [0.35040278 0.35061772]
# x-test1 7 days shape (350, 14)
# y-test 7 days shape (350,)
# x-train1 7 days reshaped (826, 14, 1)
# y_train 7 days reshaped (826, 1, 1)

# %%
x_train1.shape, x_test1.shape
# Out:
# ((826, 14, 1), (350, 14))

# %% [markdown]
# # Model

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train1.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(tf.convert_to_tensor(x_train1), tf.convert_to_tensor(y_train), epochs=20, batch_size=50, verbose=2)
# Out:
# Epoch 1/20
# 17/17 - 4s - loss: 0.0333 - 4s/epoch - 264ms/step
# Epoch 2/20
# 17/17 - 0s - loss: 0.0054 - 160ms/epoch - 9ms/step
# Epoch 3/20
# 17/17 - 0s - loss: 0.0040 - 163ms/epoch - 10ms/step
# Epoch 4/20
# 17/17 - 0s - loss: 0.0038 - 146ms/epoch - 9ms/step
# Epoch 5/20
# 17/17 - 0s - loss: 0.0038 - 179ms/epoch - 11ms/step
# Epoch 6/20
# 17/17 - 0s - loss: 0.0038 - 156ms/epoch - 9ms/step
# Epoch 7/20
# 17/17 - 0s - loss: 0.0038 - 165ms/epoch - 10ms/step
# Epoch 8/20
# 17/17 - 0s - loss: 0.0039 - 161ms/epoch - 9ms/step
# Epoch 9/20
# 17/17 - 0s - loss: 0.0038 - 154ms/epoch - 9ms/step
# Epoch 10/20
# 17/17 - 0s - loss: 0.0038 - 160ms/epoch - 9ms/step
# Epoch 11/20
# 17/17 - 0s - loss: 0.0038 - 199ms/epoch - 12ms/step
# Epoch 12/20
# 17/17 - 0s - loss: 0.0038 - 165ms/epoch - 10ms/step
# Epoch 13/20
# 17/17 - 0s - loss: 0.0038 - 171ms/epoch - 10ms/step
# Epoch 14/20
# 17/17 - 0s - loss: 0.0038 - 176ms/epoch - 10ms/step
# Epoch 15/20
# 17/17 - 0s - loss: 0.0038 - 158ms/epoch - 9ms/step
# Epoch 16/20
# 17/17 - 0s - loss: 0.0038 - 222ms/epoch - 13ms/step
# Epoch 17/20
# 17/17 - 0s - loss: 0.0038 - 166ms/epoch - 10ms/step
# Epoch 18/20
# 17/17 - 0s - loss: 0.0039 - 158ms/epoch - 9ms/step
# Epoch 19/20
# 17/17 - 0s - loss: 0.0038 - 179ms/epoch - 11ms/step
# Epoch 20/20
# 17/17 - 0s - loss: 0.0039 - 144ms/epoch - 8ms/step

# %%
'''NUM_NEURONS_FirstLayer = 128
NUM_NEURONS_SecondLayer = 64
NUM_NEURONS_ThirdLayer = 16

EPOCHS = 220
#Build the model
model = Sequential()
model.add(LSTM(NUM_NEURONS_FirstLayer,input_shape=(x_train1.shape[1],1),activation="tanh", return_sequences=True))
model.add(LSTM(NUM_NEURONS_SecondLayer,input_shape=(NUM_NEURONS_FirstLayer,1),activation="tanh"))
#model.add(LSTM(NUM_NEURONS_ThirdLayer,input_shape=(NUM_NEURONS_SecondLayer,1)))
model.add(Dense(1))


x_train1=np.asarray(x_train1).astype(np.float64)
#x_test=np.asarray(x_test).astype(np.float64)
y_train=np.asarray(y_train).astype(np.float64)
#y_test=np.asarray(y_test).astype(np.float64)


model.compile(loss='mean_absolute_error', optimizer='adam')
model.fit(tf.convert_to_tensor(x_train1), tf.convert_to_tensor(y_train), epochs=20, batch_size=50, verbose=2)'''
# Out:
# 'NUM_NEURONS_FirstLayer = 128\nNUM_NEURONS_SecondLayer = 64\nNUM_NEURONS_ThirdLayer = 16\n\nEPOCHS = 220\n#Build the model\nmodel = Sequential()\nmodel.add(LSTM(NUM_NEURONS_FirstLayer,input_shape=(x_train1.shape[1],1),activation="tanh", return_sequences=True))\nmodel.add(LSTM(NUM_NEURONS_SecondLayer,input_shape=(NUM_NEURONS_FirstLayer,1),activation="tanh"))\n#model.add(LSTM(NUM_NEURONS_ThirdLayer,input_shape=(NUM_NEURONS_SecondLayer,1)))\nmodel.add(Dense(1))\n\n\nx_train1=np.asarray(x_train1).astype(np.float64)\n#x_test=np.asarray(x_test).astype(np.float64)\ny_train=np.asarray(y_train).astype(np.float64)\n#y_test=np.asarray(y_test).astype(np.float64)\n\n\nmodel.compile(loss=\'mean_absolute_error\', optimizer=\'adam\')\nmodel.fit(tf.convert_to_tensor(x_train1), tf.convert_to_tensor(y_train), epochs=20, batch_size=50, verbose=2)'

# %%
closing_price = model.predict(x_train1)
print(closing_price.shape)
# Out:
# (826, 1)

# %%
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
a = y_train.reshape(y_train.shape[0],1)
a.shape
a = pd.DataFrame(a)
a[1] = a[0]
a.head()
a = scaler.inverse_transform(a)
a = a[0:len(a),0]

closing_price = df_cp[0:len(df_cp),0]
rms=np.sqrt(np.mean(np.power((a-closing_price),2)))
rms
# Out:
# 2.5432545086097007

# %%
plt.plot(a, color = 'red', label = 'Real Stock Close Price ')
plt.plot(closing_price, color = 'blue', label = 'Predicted Stock Close Price ')
plt.title('Stock Return Percentage Prediction(day level) by LSTM on Scaled Train Data (return percent , volume percent)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
x_test1.shape
# Out:
# (350, 14)

# %%
closing_price = model.predict(x_test1)
print(closing_price.shape)
# Out:
# (350, 1)

# %%
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
a = y_test.reshape(y_test.shape[0],1)
a.shape
a = pd.DataFrame(a)
a[1] = a[0]
a.head()
a = scaler.inverse_transform(a)
a = a[0:len(a),0]

closing_price = df_cp[0:len(df_cp),0]
rms=np.sqrt(np.mean(np.power((a-closing_price),2)))
rms
# Out:
# 2.2145619351091788

# %%
actual_pred = pd.DataFrame(closing_price, a)
actual_pred.to_csv("actual_pred_testdata_ReturnPercentage_sbi_7Days_LSTMmodel.csv")

# %%
plt.plot(a[0:len(a)-2], color = 'red', label = 'Real Stock Return Percentage ')
plt.plot(closing_price, color = 'blue', label = 'Predicted Stock Return Percentage ')
plt.title('Stock Return Percentage Prediction(day level) by LSTM on Scaled Test Data (return percent , volume percent)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
len(closing_price[0:len(closing_price)-1])
#len(closing_price)
closing_price[-3:-1]
len(a[0:len(a)-2])

# %%
#test_data_lstm = pd.read_csv("test_data_lstm.csv")

# %%
#test_case1 = test_data_lstm[len(test_data_lstm)-1:]
'''closing_price = model.predict(test_case1)
print(closing_price.shape)
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
pd.DataFrame(df_cp).head() '''

# %%
'''test_case2 = test_data_lstm[len(test_data_lstm)-2:][0:1]
closing_price = model.predict(test_case2)
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
pd.DataFrame(df_cp).head()'''

# %% [markdown]
# ###############################################################################################################################

# %%
#creating dataframe scaled
data = dt_stock.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(dt_stock)),columns=['date', 'close','volume'])
for i in range(0,len(data)):
    new_data['date'][i] = data['date'][i]
    new_data['close'][i] = data['close'][i]
    new_data['volume'][i] = data['volume'][i]


#setting index
#print(new_data.shape)
new_data.index = new_data.date
new_data.drop('date', axis=1, inplace=True)
print("data shape",new_data.shape)

#creating train and test sets
dataset = new_data.values
#print(dataset.shape)



#print(len(valid))
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
print("Scaling done")
train = scaled_data[0:int(len(scaled_data)*0.80),:]
print("train shape",train.shape)
valid = scaled_data[int(len(scaled_data)*0.80):,:]
print("test shape",valid.shape)


x_train, y_train = [], []
for i in range(90,len(train)):
    x_train.append(train[i-90:i,])
    y_train.append(train[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

print("x-train 90 days shape",x_train.shape)
print("y-shape 90 days shape",y_train.shape)

    
x_test, y_test = [], []
for i in range(90,len(valid)):
    x_test.append(valid[i-90:i,])
    y_test.append(valid[i,0])
x_test, y_test = np.array(x_test), np.array(y_test)

#x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print("x-test 90 days shape",x_test.shape)
print("y-test 90 days shape",y_test.shape)


x_train1 = np.reshape(x_train[0],(1,-1))
for i in range(1,len(x_train)):
    r1 = np.reshape(x_train[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_train1 = np.vstack((x_train1,r1))
pd.DataFrame(x_train1).to_csv("train_data_lstm.csv")
#print(pd.DataFrame(x_train1).head(3))
print("x-train1 90 days shape",x_train1.shape)
#print("x-train1 90 days head ",x_train1.head())
print("y-shape 90 days shape",y_train.shape)


x_test1 = np.reshape(x_test[0],(1,-1))
for i in range(1,len(x_test)):
    r1 = np.reshape(x_test[i],(1,-1))
    #r2 = np.reshape(x_train[1],(1,-1))
    x_test1 = np.vstack((x_test1,r1))
x_test.shape
pd.DataFrame(x_test1).to_csv("test_data_lstm.csv")

#print(pd.DataFrame(x_test).head(3))
print("x-test1 90 days shape",x_test1.shape)
print("y-test 90 days shape",y_test.shape)
# Out:
# data shape (1191, 2)
# Scaling done
# train shape (952, 2)
# test shape (239, 2)
# x-train 90 days shape (862, 90, 2)
# y-shape 90 days shape (862,)
# x-test 90 days shape (149, 90, 2)
# y-test 90 days shape (149,)
# x-train1 90 days shape (862, 180)
# y-shape 90 days shape (862,)
# x-test1 90 days shape (149, 180)
# y-test 90 days shape (149,)

# %%
x_train1 = np.reshape(x_train1, (x_train1.shape[0],x_train1.shape[1],1))
print("x-train1 90 days reshaped",x_train1.shape)
# Out:
# x-train1 90 days reshaped (862, 180, 1)

# %%
y_train = np.reshape(y_train, (y_train.shape[0],1,1))
print("y_train 90 days reshaped",y_train.shape)
# Out:
# y_train 90 days reshaped (862, 1, 1)

# %%
x_train1.shape, x_test1.shape
# Out:
# ((862, 180, 1), (149, 180))

# %%
NUM_NEURONS_FirstLayer = 128
NUM_NEURONS_SecondLayer = 64
EPOCHS = 220
#Build the model
model = Sequential()
model.add(LSTM(NUM_NEURONS_FirstLayer,input_shape=(x_train1.shape[1],1), return_sequences=True))
model.add(LSTM(NUM_NEURONS_SecondLayer,input_shape=(NUM_NEURONS_FirstLayer,1)))
model.add(Dense(1))


x_train1=np.asarray(x_train1).astype(np.float64)
#x_test=np.asarray(x_test).astype(np.float64)
y_train=np.asarray(y_train).astype(np.float64)
#y_test=np.asarray(y_test).astype(np.float64)


model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(tf.convert_to_tensor(x_train1), tf.convert_to_tensor(y_train), epochs=7, batch_size=50, verbose=2)
# Out:
# Epoch 1/7
# 18/18 - 15s - loss: 0.0345 - 15s/epoch - 830ms/step
# Epoch 2/7
# 18/18 - 9s - loss: 0.0094 - 9s/epoch - 492ms/step
# Epoch 3/7
# 18/18 - 9s - loss: 0.0073 - 9s/epoch - 487ms/step
# Epoch 4/7
# 18/18 - 9s - loss: 0.0054 - 9s/epoch - 486ms/step
# Epoch 5/7
# 18/18 - 9s - loss: 0.0044 - 9s/epoch - 484ms/step
# Epoch 6/7
# 18/18 - 9s - loss: 0.0049 - 9s/epoch - 486ms/step
# Epoch 7/7
# 18/18 - 9s - loss: 0.0048 - 9s/epoch - 482ms/step

# %%
closing_price = model.predict(x_train1)
print(closing_price.shape)
# Out:
# (862, 1)

# %%
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
a = y_train.reshape(y_train.shape[0],1)
a.shape
a = pd.DataFrame(a)
a[1] = a[0]
a.head()
a = scaler.inverse_transform(a)
a = a[0:len(a),0]

closing_price = df_cp[0:len(df_cp),0]
rms=np.sqrt(np.mean(np.power((a-closing_price),2)))
rms
# Out:
# 26.267458042769995

# %%
plt.plot(a, color = 'red', label = 'Real Stock Price Percentage')
plt.plot(closing_price, color = 'blue', label = 'Predicted Stock Price Percentage')
plt.title('Stock Returns Percentage Prediction by LSTM on Train Data( scaled)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
closing_price = model.predict(x_test1)
print(closing_price.shape)
# Out:
# (149, 1)

# %%
df_cp = pd.DataFrame(closing_price)
df_cp[1] = df_cp[0]
df_cp.head()
df_cp = scaler.inverse_transform(df_cp)
a = y_test.reshape(y_test.shape[0],1)
a.shape
a = pd.DataFrame(a)
a[1] = a[0]
a.head()
a = scaler.inverse_transform(a)
a = a[0:len(a),0]

closing_price = df_cp[0:len(df_cp),0]
rms=np.sqrt(np.mean(np.power((a-closing_price),2)))
rms
# Out:
# 28.357453465709252

# %%
plt.plot(a[0:len(a)-2], color = 'red', label = 'Real Stock Price Percentage')
plt.plot(closing_price, color = 'blue', label = 'Predicted Stock Price Percentage')
plt.title('Stock Returns Percentage Prediction by LSTM on Test Data (close, volume scaled)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
actual_pred_test = pd.DataFrame(closing_price, a)
actual_pred_test.to_csv("actual_pred_testdata_sbi2.csv")
